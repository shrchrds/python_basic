# %% [markdown]
# **118.
# Define a subprogram that will ask the user to
# enter a number and save it as the variable
# “num”. Define another subprogram that will
# use “num” and count from 1 to that number.**

# %%
def number():
    num = int(input("Enter a number: "))
    return num

def countnum(num) :
    for i in range(1,num+1) :
        print(i)

def main() :
    num = number()
    countnum(num)
    
main()
# Out:
# Enter a number: 9
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# **119.
# Define a subprogram that will ask the user to pick a low and a high number, and then generate a random number between those two values and store it in a variable called “comp_num”.**
#
# **Define another subprogram that will give the instruction “I am thinking of a number…” and then ask the user to guess the number they are thinking of.**
#
# **Define a third subprogram that will check to see if the comp_num is the same as the user’s guess. If it is, it should display the message “Correct, you win”, otherwise it should keep looping, telling the user if they are too low or too high and asking them to guess again until they guess correctly.**

# %%
import random

# %%
def random_number():
    low_num = int(input("Enter a lower number: "))
    high_num = int(input("Enter a higher number: "))
    comp_num = random.randint(low_num, high_num)
    return comp_num

def guess_number():
    print("I am thinking of a number…")
    guess = int(input("guess the number they are thinking of: "))
    return guess

def check_guess():
    comp_num = random_number()
    guess = guess_number()
    
    while guess != comp_num :
        
        if guess < comp_num :
            print("Too Low. Enter higher number: ")
        elif guess > comp_num :
            print("Too High. Enter lower number: ")
            
        guess = guess_number()
        
    else:
        print("Correct, You Win!")
        
check_guess()
# Out:
# Enter a lower number: 1
# Enter a higher number: 9
# I am thinking of a number…
# guess the number they are thinking of: 1
# Too Low. Enter higher number:
# I am thinking of a number…
# guess the number they are thinking of: 9
# Too High. Enter lower number:
# I am thinking of a number…
# guess the number they are thinking of: 2
# Too Low. Enter higher number:
# I am thinking of a number…
# guess the number they are thinking of: 8
# Too High. Enter lower number:
# I am thinking of a number…
# guess the number they are thinking of: 3
# Too Low. Enter higher number:
# I am thinking of a number…
# guess the number they are thinking of: 7
# Too High. Enter lower number:
# I am thinking of a number…
# guess the number they are thinking of: 4
# Too Low. Enter higher number:
# I am thinking of a number…
# guess the number they are thinking of: 6
# Correct, You Win!

# %% [markdown]
# **120.
# Display the following menu to the user:
#     1) Addition 2) Substraction. Enter 1 or 2.**
#
# **If they enter a 1, it should run a subprogram that will generate two random numbers between 5 and 20, and ask the user to add them together. Work out the correct answer and return both the user’s answer and the correct answer.**
#
# **If they entered 2 as their selection on the menu, it
# should run a subprogram that will generate one number
# between 25 and 50 and another number between 1 and
# 25 and ask them to work out num1 minus num2. This
# way they will not have to worry about negative answers.
# Return both the user’s answer and the correct answer.**
#
# **Create another subprogram that will check if the user’s
# answer matches the actual answer. If it does, display
# “Correct”, otherwise display a message that will say
# “Incorrect, the answer is” and display the real answer.
# If they do not select a relevant option on the first menu
# you should display a suitable message.**

# %%
import random
def add():
    n1 = random.randint(5,20)
    n2 = random.randint(5,20)
    summ = n1 + n2
    guess_sum = int(input(f"What is sum of {n1} and {n2}: "))
    print(f"Your answer: {guess_sum} and correct answer: {summ}")
    return guess_sum, summ
        
def substract():
    n1 = random.randint(25,50)
    n2 = random.randint(1,25)
    substraction = n1 - n2
    guess_sub = int(input(f"What is substraction of {n1} and {n2}: "))
    print(f"Your answer: {guess_sub} and correct answer: {substraction}")
    return guess_sub, substraction

def check_correct(user_ans, ans):
    if user_ans == ans :
        print("Correct")
    else:
        print(f"Incorrect, the answer is {ans}")
    
    
def addsubstract():
    num = input("Enter 1. for Addition, 2. for Substraction: ")
    if num == '1' :
        user_ans, ans = add()
        check_correct(user_ans, ans)
        
    elif num == '2' :
        user_ans, ans = substract()
        check_correct(user_ans, ans)
        
    else:
        print("Enter correct number: ")
addsubstract()
# Out:
# Enter 1. for Addition, 2. for Substraction: 1
# What is sum of 13 and 18: 31
# Your answer: 31 and correct answer: 31
# Correct

# %% [markdown]
# **121.
# Create a program that will allow the user to easily manage a list of names. You should
# display a menu that will allow them to add a name to the list, change a name in the
# list, delete a name from the list or view all the names in the list. There should also be a
# menu option to allow the user to end the program. If they select an option that is not
# relevant, then it should display a suitable message. After they have made a selection
# to either add a name, change a name, delete a name or view all the names, they
# should see the menu again without having to restart the program. The program
# should be made as easy to use as possible.**

# %%
names = []
# add name to list
def add_name() :
    name = input("Enter a name to add in list: ")
    names.append(name)
    return names

# change name in list :

def change_name() :
    print(names)
    name_number = int(input("Enter a name number to change: "))
    new_name = input("Enter a name you want to change: ")
    names[name_number - 1] = new_name
    return names

# delete name from list :

def delete_name() :
    print(names)
    delete = int(input("Enter a name number to delete: "))
    del names[delete - 1]
    return names

# view names

def view_names():
    for i in names :
        print(i)
    print()

# manage list of names
def manage_names() :
    repeat = "y"
    while repeat == 'y':
        menu = input("""Enter from following
                        1 to add a name to list, 
                        2 to change a name in list, 
                        3 to delete a name from list, 
                        4 to view all names in the list,
                        5 to end program.\n""")
        if menu == '1' :
            add_name()
        elif menu == '2' :
            change_name()
        elif menu == '3' :
            delete_name()
        elif menu == '4' :
            view_names()
        elif menu == '5' :
            repeat = 'n'
        else:
            print("Enter correct input: ")
        
manage_names()
# Out:
# Enter from following
#                         1 to add a name to list,
#                         2 to change a name in list,
#                         3 to delete a name from list,
#                         4 to view all names in the list,
#                         5 to end program.
# 1
# Enter a name to add in list: Rohan
# Enter from following
#                         1 to add a name to list,
#                         2 to change a name in list,
#                         3 to delete a name from list,
#                         4 to view all names in the list,
#                         5 to end program.
# Shiv
# Enter correct input:
# Enter from following
#                         1 to add a name to list,
#                         2 to change a name in list,
#                         3 to delete a name from list,
#                         4 to view all names in the list,
#                         5 to end program.
# 1
# Enter a name to add in list: Shiv
# Enter from following
# ...

# %% [markdown]
# ### 122. Create the following menu:
#
#     1. Add to file
#     2. view all records
#     3. Quit Program
#
# **Enter number of your selection:
# If the user selects 1, allow them to add to a file
# called Salaries.csv which will store their name
# and salary. If they select 2 it should display all
# records in the Salaries.csv file. If they select 3 it
# should stop the program. If they select an
# incorrect option they should see an error
# message. They should keep returning to the
# menu until they select option 3.**

# %%
import csv

def add_to_file() :
    with open("Salaries.csv", "a") as file:
        name = input("Enter your name: ")
        salary = input("Enter your salary: ")
        record = name + "," + salary + "\n"
        file.write(record)
    
def view_csv() :
    with open("Salaries.csv", "r") as file:
        for row in file :
            print(row)

def update_csv() :
    repeat = 'y'
    
    while repeat == 'y':
        menu = input("""Enter from following
                            1. add to file, 
                            2. to view all records, 
                            3. to Quit Program\n""")
        if menu == '1' :
            add_to_file()
            
        elif menu == '2' :
            view_csv()
                    
        elif menu == '3' :
            repeat = 'n'
                    
        else:
            print("Enter appropriate number: ")
            
# calling function
update_csv()
# Out:
# Enter from following
#                             1. add to file,
#                             2. to view all records,
#                             3. to Quit Program
# Rohan
# Enter appropriate number:
# Enter from following
#                             1. add to file,
#                             2. to view all records,
#                             3. to Quit Program
# 1
# Enter your name: Rohan
# Enter your salary: 75000
# Enter from following
#                             1. add to file,
#                             2. to view all records,
#                             3. to Quit Program
# Pranit
# Enter appropriate number:
# Enter from following
#                             1. add to file,
#                             2. to view all records,
#                             3. to Quit Program
# 1
# Enter your name: Pranit
# Enter your salary: 125000
# Enter from following
#                             1. add to file,
#                             2. to view all records,
# ...

# %% [markdown]
# **123.
# In Python, it is not technically possible to directly
# delete a record from a .csv file. Instead you need
# to save the file to a temporary list in Python,
# make the changes to the list and then overwrite
# the original file with the temporary list.
# Change the previous program to allow you to do
# this. Your menu should now look like this:**
#
#     1. Add to file
#     2. view all records
#     3. Delete a record
#     4. Quit Program
# Enter number of your selection:

# %%
import csv

def add_to_file() :
    with open("Salaries.csv", "a") as file:
        name = input("Enter your name: ")
        salary = input("Enter your salary: ")
        record = name + "," + salary + "\n"
        file.write(record)
    
def view_csv() :
    with open("Salaries.csv", "r") as file:
        for row in file :
            print(row)
            
def delete_csv() :
    with open("Salaries.csv", "r") as file:
        i = 0
        tmplist = []
        for row in file :
            tmplist.append(row)
    for row in tmplist :
        print(i, row)
        i += 1 
        
    row_to_delete = int(input("Enter a row number to delete: "))
    
    del tmplist[row_to_delete - 1]
    
    with open("Salaries.csv", "w") as file:
        for row in tmplist :
            file.write(row)

def update_csv() :
    repeat = 'y'
    
    while repeat == 'y':
        menu = input("""Enter from following
                            1. add to file, 
                            2. to view all records, 
                            3. to delete a record,
                            4. to Quit Program\n""")
        if menu == '1' :
            with open("Salaries.csv", "a") as file:
                name = input("Enter your name: ")
                salary = input("Enter your salary: ")
                record = name + "," + salary + "\n"
                file.write(record)
        elif menu == '2' :
            with open("Salaries.csv", "r") as file:
                for row in file :
                    print(row)
                    
        elif menu == '3' :
            delete_csv()
                    
        elif menu == '4' :
            repeat = 'n'
                    
        else:
            print("Enter appropriate number: ")
            
# calling function
update_csv()
# Out:
# Enter from following
#                             1. add to file,
#                             2. to view all records,
#                             3. to delete a record,
#                             4. to Quit Program
# 1
# Enter your name: Ranjeet
# Enter your salary: 45000
# Enter from following
#                             1. add to file,
#                             2. to view all records,
#                             3. to delete a record,
#                             4. to Quit Program
# 1
# Enter your name: Amruta
# Enter your salary: 15000
# Enter from following
#                             1. add to file,
#                             2. to view all records,
#                             3. to delete a record,
#                             4. to Quit Program
# 2
# Rohan,75000
#
# Pranit,125000
#
# Ranjeet,45000
#
# Amruta,15000
#
# Enter from following
#                             1. add to file,
#                             2. to view all records,
# ...
